# %% [markdown]
# <a href="https://colab.research.google.com/github/saraAzm/Farstarabar/blob/master/Scene_Parsing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/CSAILVision/semantic-segmentation-pytorch.git
# Out:
# Cloning into 'semantic-segmentation-pytorch'...
# remote: Enumerating objects: 1170, done.
# remote: Total 1170 (delta 0), reused 0 (delta 0), pack-reused 1170
# Receiving objects: 100% (1170/1170), 5.04 MiB | 27.59 MiB/s, done.
# Resolving deltas: 100% (707/707), done.

# %%
# !wget -O /content/semantic-segmentation-pytorch/data/ADEChallengeData2016.zip http://data.csail.mit.edu/places/ADEchallenge/ADEChallengeData2016.zip
# Out:
# --2023-06-10 11:16:25--  http://data.csail.mit.edu/places/ADEchallenge/ADEChallengeData2016.zip
# Resolving data.csail.mit.edu (data.csail.mit.edu)... 128.52.129.40
# Connecting to data.csail.mit.edu (data.csail.mit.edu)|128.52.129.40|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 967382037 (923M) [application/zip]
# Saving to: ‘/content/semantic-segmentation-pytorch/data/ADEChallengeData2016.zip’
#
# /content/semantic-s 100%[===================>] 922.57M  90.7MB/s    in 12s
#
# 2023-06-10 11:16:37 (79.2 MB/s) - ‘/content/semantic-segmentation-pytorch/data/ADEChallengeData2016.zip’ saved [967382037/967382037]

# %%
! unzip /content/semantic-segmentation-pytorch/data/ADEChallengeData2016.zip -d /content/semantic-segmentation-pytorch/data
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/semantic-segmentation-pytorch/data/ADEChallengeData2016/annotations/training/ADE_train_00019018.png
#   inflating: /content/semantic-segmentation-pytorch/data/ADEChallengeData2016/annotations/training/ADE_train_00010086.png
#   inflating: /content/semantic-segmentation-pytorch/data/ADEChallengeData2016/annotations/training/ADE_train_00002526.png
#   inflating: /content/semantic-segmentation-pytorch/data/ADEChallengeData2016/annotations/training/ADE_train_00002954.png
#   inflating: /content/semantic-segmentation-pytorch/data/ADEChallengeData2016/annotations/training/ADE_train_00007278.png
#   inflating: /content/semantic-segmentation-pytorch/data/ADEChallengeData2016/annotations/training/ADE_train_00012415.png
#   inflating: /content/semantic-segmentation-pytorch/data/ADEChallengeData2016/annotations/training/ADE_train_00012867.png
# ...

# %%
! rm /content/semantic-segmentation-pytorch/data/ADEChallengeData2016.zip

# %%
# !pip install yacs
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python /content/semantic-segmentation-pytorch/train.py
# Out:
# /content/semantic-segmentation-pytorch/train.py:209: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   assert LooseVersion(torch.__version__) >= LooseVersion('0.4.0'), \
# [2023-06-10 17:18:01,724 INFO train.py line 240 93853] Loaded configuration file /content/semantic-segmentation-pytorch/config/ade20k-resnet50dilated-ppm_deepsup.yaml
# [2023-06-10 17:18:01,724 INFO train.py line 241 93853] Running with config:
# DATASET:
#   imgMaxSize: 1000
#   imgSizes: (300, 375, 450, 525, 600)
#   list_train: /content/semantic-segmentation-pytorch/data/training.odgt
#   list_val: /content/semantic-segmentation-pytorch/data/validation.odgt
#   num_class: 150
#   padding_constant: 8
#   random_flip: True
#   root_dataset: /content/semantic-segmentation-pytorch/data/
#   segm_downsampling_rate: 8
# DIR: /content/semantic-segmentation-pytorch/ckpt/ade20k-resnet50dilated-ppm_deepsup
# MODEL:
#   arch_decoder: ppm_deepsup
# ...

# %%
# !python /content/semantic-segmentation-pytorch/test.py --imgs "/content/semantic-segmentation-pytorch/teaser/ADE_test_00000015.jpg"
# !python /content/semantic-segmentation-pytorch/test.py --imgs "/content/semantic-segmentation-pytorch/teaser/ADE_test_00000229.jpg"
# !python /content/semantic-segmentation-pytorch/test.py --imgs "/content/semantic-segmentation-pytorch/teaser/ADE_test_00000466.jpg"
# !python /content/semantic-segmentation-pytorch/test.py --imgs "/content/semantic-segmentation-pytorch/teaser/ADE_test_00000467.jpg"
# !python /content/semantic-segmentation-pytorch/test.py --imgs "/content/semantic-segmentation-pytorch/teaser/ADE_test_00000593.jpg"
# !python /content/semantic-segmentation-pytorch/test.py --imgs "/content/semantic-segmentation-pytorch/teaser/ADE_val_00000278.png"
# !python /content/semantic-segmentation-pytorch/test.py --imgs "/content/semantic-segmentation-pytorch/teaser/ADE_val_00001519.png"
# !python /content/semantic-segmentation-pytorch/test.py --imgs "/content/semantic-segmentation-pytorch/teaser/ADE_test_00001914.jpg"
# !python /content/semantic-segmentation-pytorch/test.py --imgs "/content/semantic-segmentation-pytorch/teaser/ADE_test_00000584.jpg"
# !python /content/semantic-segmentation-pytorch/test.py --imgs "/content/semantic-segmentation-pytorch/teaser/ADE_test_00000304.jpg"
# Out:
# /content/semantic-segmentation-pytorch/test.py:134: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   assert LooseVersion(torch.__version__) >= LooseVersion('0.4.0'), \
# [2023-06-10 19:52:51,850 INFO test.py line 172 133807] Loaded configuration file /content/semantic-segmentation-pytorch/config/ade20k-resnet50dilated-ppm_deepsup.yaml
# [2023-06-10 19:52:51,851 INFO test.py line 173 133807] Running with config:
# DATASET:
#   imgMaxSize: 1000
#   imgSizes: (300, 375, 450, 525, 600)
#   list_train: /content/semantic-segmentation-pytorch/data/training.odgt
#   list_val: /content/semantic-segmentation-pytorch/data/validation.odgt
#   num_class: 150
#   padding_constant: 8
#   random_flip: True
#   root_dataset: /content/semantic-segmentation-pytorch/data/
#   segm_downsampling_rate: 8
# DIR: /content/semantic-segmentation-pytorch/ckpt/ade20k-resnet50dilated-ppm_deepsup
# MODEL:
#   arch_decoder: ppm_deepsup
# ...

# %%
# !pip install frozendict -U
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 3.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: frozendict
#     Found existing installation: frozendict 2.3.7
#     Uninstalling frozendict-2.3.7:
#       Successfully uninstalled frozendict-2.3.7
# ...

# %%
# !zip -r "/content/semantic-segmentation-pytorch.zip" "/content/semantic-segmentation-pytorch"
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/semantic-segmentation-pytorch/data/ADEChallengeData2016/annotations/validation/ADE_val_00001857.png (deflated 8%)
#   adding: content/semantic-segmentation-pytorch/data/ADEChallengeData2016/annotations/validation/ADE_val_00001649.png (deflated 20%)
#   adding: content/semantic-segmentation-pytorch/data/ADEChallengeData2016/annotations/validation/ADE_val_00001172.png (deflated 6%)
#   adding: content/semantic-segmentation-pytorch/data/ADEChallengeData2016/annotations/validation/ADE_val_00001208.png (deflated 3%)
#   adding: content/semantic-segmentation-pytorch/data/ADEChallengeData2016/annotations/validation/ADE_val_00000778.png (deflated 2%)
#   adding: content/semantic-segmentation-pytorch/data/ADEChallengeData2016/annotations/validation/ADE_val_00001685.png (deflated 14%)
#   adding: content/semantic-segmentation-pytorch/data/ADEChallengeData2016/annotations/validation/ADE_val_00000403.png (deflated 12%)
# ...
